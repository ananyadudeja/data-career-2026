# %%
# %pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.3 MB 9.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.7/8.3 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.3 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 10.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 15.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ----------------- ---------------------- 3.1/7.2 MB 14.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.3/7.2 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 15.0 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
# ...

# %%
import pandas as pd
import seaborn as sns # Standard library for datasets
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Load the dataset
df = sns.load_dataset('tips')

# %%
# Save it as data.csv so you can use it for your task
df.to_csv('data.csv', index=False)
print("Dataset 'data.csv' is ready!")
# Out:
# Dataset 'data.csv' is ready!
